# %%
import pandas as pd

# %%
df = pd.read_csv("people_modified_data.csv")

# %%
df.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3      4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4      5  9afFEafAe1CBBB9    Lindsey      Rice  Female
#
#                            Email               Phone Date of birth  \
# 0            pwarner@example.org        857.139.8239    2014-01-27
# 1  fergusonkatherine@example.net     +1-950-759-8687    1931-07-26
# 2            fhoward@example.org       (599)782-0605    2013-11-25
# 3          zjohnston@example.com     +1-939-130-6258    2012-11-17
# 4               elin@example.net  (390)417-1635x3010    1923-04-15
#
#                   Job Title
# 0         Probation officer
# 1                    Dancer
# 2                      Copy
# 3  Counselling psychologist
# 4       Biomedical engineer

# %%
df.columns
# Out:
# Index(['Index', 'User Id', 'First Name', 'Last Name', 'Sex', 'Email', 'Phone',
#        'Date of birth', 'Job Title'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Index             int64
# User Id          object
# First Name       object
# Last Name        object
# Sex              object
# Email            object
# Phone            object
# Date of birth    object
# Job Title        object
# dtype: object

# %%
#  If we want to get some description of data we use describe() method

df.describe()  # By default it will give the description of numberic columns
# Out:
#              Index
# count  1000.000000
# mean    500.500000
# std     288.819436
# min       1.000000
# 25%     250.750000
# 50%     500.500000
# 75%     750.250000
# max    1000.000000

# %%
#  to get some statistics of categorical data type

# %%
df.dtypes
# Out:
# Index             int64
# User Id          object
# First Name       object
# Last Name        object
# Sex              object
# Email            object
# Phone            object
# Date of birth    object
# Job Title        object
# dtype: object

# %%
df.dtypes == "object"
# Out:
# Index            False
# User Id           True
# First Name        True
# Last Name         True
# Sex               True
# Email             True
# Phone             True
# Date of birth     True
# Job Title         True
# dtype: bool

# %%
df.dtypes[df.dtypes == "object"]
# Out:
# User Id          object
# First Name       object
# Last Name        object
# Sex              object
# Email            object
# Phone            object
# Date of birth    object
# Job Title        object
# dtype: object

# %%
df.dtypes[df.dtypes == "object"].index
# Out:
# Index(['User Id', 'First Name', 'Last Name', 'Sex', 'Email', 'Phone',
#        'Date of birth', 'Job Title'],
#       dtype='object')

# %%
df[df.dtypes[df.dtypes == "object"].index]
# Out:
#              User Id First Name Last Name     Sex  \
# 0    8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1    3d5AD30A4cD38ed         Jo    Rivers  Female
# 2    810Ce0F276Badec     Sheryl    Lowery  Female
# 3    BF2a889C00f0cE1    Whitney    Hooper    Male
# 4    9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..               ...        ...       ...     ...
# 995  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997  2adde51d8B8979E      Cathy  Mckinney  Female
# 998  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# 2              fhoward@example.org          (599)782-0605    2013-11-25
# ...

# %%
df[df.dtypes[df.dtypes == "object"].index].describe()
# Out:
#                 User Id First Name Last Name   Sex                Email  \
# count              1000       1000      1000  1000                 1000
# unique             1000        526       628     2                 1000
# top     8717bbf45cCDbEe      Lydia      Duke  Male  pwarner@example.org
# freq                  1          6         6   506                    1
#
#                Phone Date of birth         Job Title
# count           1000          1000              1000
# unique          1000           991               519
# top     857.139.8239    1955-07-31  Paediatric nurse
# freq               1             2                 7

# %%
df.columns
# Out:
# Index(['Index', 'User Id', 'First Name', 'Last Name', 'Sex', 'Email', 'Phone',
#        'Date of birth', 'Job Title'],
#       dtype='object')

# %%
df[['First Name', 'Last Name']]
# Out:
#     First Name Last Name
# 0       Shelia   Mahoney
# 1           Jo    Rivers
# 2       Sheryl    Lowery
# 3      Whitney    Hooper
# 4      Lindsey      Rice
# ..         ...       ...
# 995       Kurt    Bryant
# 996      Donna     Barry
# 997      Cathy  Mckinney
# 998   Jermaine    Phelps
# 999        Lee      Tran
#
# [1000 rows x 2 columns]

# %%
# if we want to get data from 4 to 10 row

df[['First Name', 'Last Name']][4:11]  # like list slicing
# Out:
#    First Name Last Name
# 4     Lindsey      Rice
# 5      Sherry  Caldwell
# 6      Ernest   Hoffman
# 7       Doris  Andersen
# 8      Cheryl      Mays
# 9       Harry  Mitchell
# 10      Casey     Ayala

# %%
#  to get every alternate record
df[['First Name', 'Last Name']][4:11:2]
# Out:
#    First Name Last Name
# 4     Lindsey      Rice
# 6      Ernest   Hoffman
# 8      Cheryl      Mays
# 10      Casey     Ayala

# %%
#  we can also add a new column to dataframe

df["new_col"] = 0 # set 0 for each row of new_col

# %%
df.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3      4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4      5  9afFEafAe1CBBB9    Lindsey      Rice  Female
#
#                            Email               Phone Date of birth  \
# 0            pwarner@example.org        857.139.8239    2014-01-27
# 1  fergusonkatherine@example.net     +1-950-759-8687    1931-07-26
# 2            fhoward@example.org       (599)782-0605    2013-11-25
# 3          zjohnston@example.com     +1-939-130-6258    2012-11-17
# 4               elin@example.net  (390)417-1635x3010    1923-04-15
#
#                   Job Title  new_col
# 0         Probation officer        0
# 1                    Dancer        0
# 2                      Copy        0
# 3  Counselling psychologist        0
# 4       Biomedical engineer        0

# %%
# if we want to create a column which is summation of two or more columns

df["full_name"] = df["First Name"] + df["Last Name"]

# %%
df.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3      4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4      5  9afFEafAe1CBBB9    Lindsey      Rice  Female
#
#                            Email               Phone Date of birth  \
# 0            pwarner@example.org        857.139.8239    2014-01-27
# 1  fergusonkatherine@example.net     +1-950-759-8687    1931-07-26
# 2            fhoward@example.org       (599)782-0605    2013-11-25
# 3          zjohnston@example.com     +1-939-130-6258    2012-11-17
# 4               elin@example.net  (390)417-1635x3010    1923-04-15
#
#                   Job Title  new_col      full_name
# 0         Probation officer        0  SheliaMahoney
# 1                    Dancer        0       JoRivers
# 2                      Copy        0   SherylLowery
# ...

# %%
df["Sex"]
# Out:
# 0        Male
# 1      Female
# 2      Female
# 3        Male
# 4      Female
#         ...
# 995    Female
# 996    Female
# 997    Female
# 998      Male
# 999    Female
# Name: Sex, Length: 1000, dtype: object

# %%
#  if i want to get insights of this column i.e how many categories of object
pd.Categorical(df["Sex"])
# Out:
# ['Male', 'Female', 'Female', 'Male', 'Female', ..., 'Female', 'Female', 'Female', 'Male', 'Female']
# Length: 1000
# Categories (2, object): ['Female', 'Male']

# %%
pd.Categorical(df["Last Name"])  # If i want to know the number of unique Last Name
# Out:
# ['Mahoney', 'Rivers', 'Lowery', 'Hooper', 'Rice', ..., 'Bryant', 'Barry', 'Mckinney', 'Phelps', 'Tran']
# Length: 1000
# Categories (628, object): ['Abbott', 'Acevedo', 'Acosta', 'Adkins', ..., 'Zamora', 'Zavala', 'Zhang', 'Zuniga']

# %%
#  we can also use unique()

df["Last Name"].unique()
# Out:
# array(['Mahoney', 'Rivers', 'Lowery', 'Hooper', 'Rice', 'Caldwell',
#        'Hoffman', 'Andersen', 'Mays', 'Mitchell', 'Ayala', 'Huff',
#        'Barnes', 'Lowe', 'Davis', 'Abbott', 'Mckinney', 'Macias',
#        'Jenkins', 'Mcmahon', 'Travis', 'Hawkins', 'Oconnell', 'Walton',
#        'Sweeney', 'Wu', 'Myers', 'Nash', 'Delgado', 'Hahn', 'Gomez',
#        'Clarke', 'Reyes', 'Weber', 'Vaughn', 'Lambert', 'Hess', 'Sherman',
#        'Velez', 'Moore', 'Herrera', 'Berger', 'Bolton', 'Duke', 'Rosales',
#        'Wall', 'Ramirez', 'Mercer', 'Zavala', 'Carey', 'Hobbs', 'Reilly',
#        'Conrad', 'Cole', 'Donovan', 'Little', 'Dawson', 'Page',
#        'Bradshaw', 'Daniels', 'Harding', 'Olson', 'Haas', 'Fuller',
#        'Valenzuela', 'Steele', 'Mcguire', 'Doyle', 'Neal', 'Meyer',
#        'Pratt', 'Payne', 'Mccoy', 'Sparks', 'Conley', 'Grant', 'Key',
#        'Humphrey', 'Haney', 'Henry', 'Long', 'Mccarty', 'Davila',
#        'Blankenship', 'Mclean', 'Brooks', 'Stevenson', 'Holmes',
# ...

# %%
len(df["Last Name"].unique())
# Out:
# 628

# %%
df.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3      4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4      5  9afFEafAe1CBBB9    Lindsey      Rice  Female
#
#                            Email               Phone Date of birth  \
# 0            pwarner@example.org        857.139.8239    2014-01-27
# 1  fergusonkatherine@example.net     +1-950-759-8687    1931-07-26
# 2            fhoward@example.org       (599)782-0605    2013-11-25
# 3          zjohnston@example.com     +1-939-130-6258    2012-11-17
# 4               elin@example.net  (390)417-1635x3010    1923-04-15
#
#                   Job Title  new_col      full_name
# 0         Probation officer        0  SheliaMahoney
# 1                    Dancer        0       JoRivers
# 2                      Copy        0   SherylLowery
# ...

# %%
#  FILTER OPERATIONS

# now if would like to know about those persons have age greater than 14

# df[df["Age"] > 14]

# now if would like to know about those persons have age lesser than or equal to 14
# len(df) - len(df[df["Age"] > 14])

#  If i would like to find their names 

# df[df["Age"] > 14]["First Name"]

#  if i would like to find those total number of persons

# len(df[df["Age"] > 14])

#  similary we can find any data of those people who are greater than 14

# %%
#  let us find data of males

df["Sex"] == "Male"
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998     True
# 999    False
# Name: Sex, Length: 1000, dtype: bool

# %%
df[df["Sex"] == "Male"]
# Out:
#      Index          User Id First Name Last Name   Sex  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney  Male
# 3        4  BF2a889C00f0cE1    Whitney    Hooper  Male
# 5        6  aF75e6dDEBC5b66     Sherry  Caldwell  Male
# 6        7  efeb05c7Cc94EA3     Ernest   Hoffman  Male
# 7        8  fb1BF3FED57E9d7      Doris  Andersen  Male
# ..     ...              ...        ...       ...   ...
# 986    987  9871eF832fab828     Lonnie  Reynolds  Male
# 989    990  1Dba7B14a3E44EE       Omar      Kent  Male
# 990    991  CBfaec1d322EBEe      Lydia    Obrien  Male
# 994    995  E54d5DDEeE6569E    Beverly      Ball  Male
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps  Male
#
#                            Email                  Phone Date of birth  \
# 0            pwarner@example.org           857.139.8239    2014-01-27
# 3          zjohnston@example.com        +1-939-130-6258    2012-11-17
# 5          kaitlin13@example.net             8537800927    1917-08-06
# ...

# %%
len(df[df["Sex"] == "Male"])
# Out:
# 506

# %%
df[df["Sex"] == "Male"]["First Name"]
# Out:
# 0        Shelia
# 3       Whitney
# 5        Sherry
# 6        Ernest
# 7         Doris
#          ...
# 986      Lonnie
# 989        Omar
# 990       Lydia
# 994     Beverly
# 998    Jermaine
# Name: First Name, Length: 506, dtype: object

# %%
df.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3      4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4      5  9afFEafAe1CBBB9    Lindsey      Rice  Female
#
#                            Email               Phone Date of birth  \
# 0            pwarner@example.org        857.139.8239    2014-01-27
# 1  fergusonkatherine@example.net     +1-950-759-8687    1931-07-26
# 2            fhoward@example.org       (599)782-0605    2013-11-25
# 3          zjohnston@example.com     +1-939-130-6258    2012-11-17
# 4               elin@example.net  (390)417-1635x3010    1923-04-15
#
#                   Job Title  new_col      full_name
# 0         Probation officer        0  SheliaMahoney
# 1                    Dancer        0       JoRivers
# 2                      Copy        0   SherylLowery
# ...

# %%
#  ROW SELECTION

# now we will find even records from 0 to 100

df[0:100:2]
# Out:
#     Index          User Id First Name    Last Name     Sex  \
# 0       1  8717bbf45cCDbEe     Shelia      Mahoney    Male
# 2       3  810Ce0F276Badec     Sheryl       Lowery  Female
# 4       5  9afFEafAe1CBBB9    Lindsey         Rice  Female
# 6       7  efeb05c7Cc94EA3     Ernest      Hoffman    Male
# 8       9  421fAB9a3b98F30     Cheryl         Mays    Male
# 10     11  44FAA9C3CE8DB2B      Casey        Ayala    Male
# 12     13  CDA21B6e83Cafe3      Eddie       Barnes  Female
# 14     15  b4bE3BfBfeBC29e  Priscilla        Davis    Male
# 16     17  cEfCEAB1306DbCb    Nicolas     Mckinney    Male
# 18     19  CF091D6b9Dd4F9c   Courtney      Jenkins  Female
# 20     21  7B247Ca7BbA098d      Emily       Travis    Male
# 22     23  d62fFce33bbccAC     Ernest     Oconnell    Male
# 24     25  be6BBa9EBFeBFcc      Roger      Sweeney  Female
# 26     27  EEA3bcfe1c7aEAf  Catherine        Myers    Male
# 28     29  EC9BCcb3ccEAdE9      Corey      Delgado    Male
# ...

# %%
#  iloc[] method

df.iloc[0:3]
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
#
#                            Email            Phone Date of birth  \
# 0            pwarner@example.org     857.139.8239    2014-01-27
# 1  fergusonkatherine@example.net  +1-950-759-8687    1931-07-26
# 2            fhoward@example.org    (599)782-0605    2013-11-25
#
#            Job Title  new_col      full_name
# 0  Probation officer        0  SheliaMahoney
# 1             Dancer        0       JoRivers
# 2               Copy        0   SherylLowery

# %%
#  loc[] method

df.loc[0:3]  # it will include 3
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3      4  BF2a889C00f0cE1    Whitney    Hooper    Male
#
#                            Email            Phone Date of birth  \
# 0            pwarner@example.org     857.139.8239    2014-01-27
# 1  fergusonkatherine@example.net  +1-950-759-8687    1931-07-26
# 2            fhoward@example.org    (599)782-0605    2013-11-25
# 3          zjohnston@example.com  +1-939-130-6258    2012-11-17
#
#                   Job Title  new_col      full_name
# 0         Probation officer        0  SheliaMahoney
# 1                    Dancer        0       JoRivers
# 2                      Copy        0   SherylLowery
# 3  Counselling psychologist        0  WhitneyHooper

# %%
#  The main difference between these two methods is that iloc[] method takes in-built indexes
#  while loc[] method takes named indexes

# %%
df.iloc[0:3 , [0,1,2]]
# Out:
#    Index          User Id First Name
# 0      1  8717bbf45cCDbEe     Shelia
# 1      2  3d5AD30A4cD38ed         Jo
# 2      3  810Ce0F276Badec     Sheryl

# %%
df.loc[0:3 , ['Index','User Id' , 'First Name']]
# Out:
#    Index          User Id First Name
# 0      1  8717bbf45cCDbEe     Shelia
# 1      2  3d5AD30A4cD38ed         Jo
# 2      3  810Ce0F276Badec     Sheryl
# 3      4  BF2a889C00f0cE1    Whitney
