# %%
import pandas as pd

# %%
df = pd.read_csv("titanic_dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
type(df["Name"])
# Out:
# pandas.core.series.Series

# %%
#  if we want to get data from 2nd to 10th index

df["Name"][2:11]
# Out:
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# Name: Name, dtype: object

# %%
# to find total number of records

len(df)
# Out:
# 891

# %%
list1 = ["a" , "b" , "c" , "d" , "e" , "f" ]

#  we can convert this list into a series

pd.Series(list1)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# 5    f
# dtype: object

# %%
# df["Name"]  we have this series.
#  we can convert this series into a list

list(df["Name"])
# Out:
# ['Braund, Mr. Owen Harris',
#  'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#  'Heikkinen, Miss. Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry',
#  'Moran, Mr. James',
#  'McCarthy, Mr. Timothy J',
#  'Palsson, Master. Gosta Leonard',
#  'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#  'Nasser, Mrs. Nicholas (Adele Achem)',
#  'Sandstrom, Miss. Marguerite Rut',
#  'Bonnell, Miss. Elizabeth',
#  'Saundercock, Mr. William Henry',
#  'Andersson, Mr. Anders Johan',
#  'Vestrom, Miss. Hulda Amanda Adolfina',
#  'Hewlett, Mrs. (Mary D Kingcome) ',
#  'Rice, Master. Eugene',
#  'Williams, Mr. Charles Eugene',
#  'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#  'Masselmani, Mrs. Fatima',
#  'Fynney, Mr. Joseph J',
#  'Beesley, Mr. Lawrence',
#  'McGowan, Miss. Anna "Annie"',
#  'Sloper, Mr. William Thompson',
#  'Palsson, Miss. Torborg Danira',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
# ...

# %%
df["Name"][2:7]
# Out:
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# 5                                Moran, Mr. James
# 6                         McCarthy, Mr. Timothy J
# Name: Name, dtype: object

# %%
# Now we have indexes from 2 to 6 in this series which is by default 

#  if we want to change these indexes and set our own indexes

# for this we have to convert this series into a list and pass into pd.Series with index = []

pd.Series(list(df["Name"][2:7]) , index = [0,1,2,3,4])
# Out:
# 0                          Heikkinen, Miss. Laina
# 1    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 2                        Allen, Mr. William Henry
# 3                                Moran, Mr. James
# 4                         McCarthy, Mr. Timothy J
# dtype: object

# %%
#  if we will not convert the series firstly into a list , then it means that we are passing an series
#  into pd.Series() and then it will do data NAN

pd.Series(df["Name"][2:7] , index = [0,1,2,3,4])
# Out:
# 0                                             NaN
# 1                                             NaN
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
s = pd.Series(list(df["Name"][2:7]) , index = ["a","b","c","d","e"])

# %%
s1 = df["Name"][5:10]

# %%
s + s1  # By default it will concatenate all the indexes but will nullify all the data
# Out:
# a    NaN
# b    NaN
# c    NaN
# d    NaN
# e    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# dtype: object

# %%
s2 = s.append(s1)
# Out:
# /tmp/ipykernel_433/3943142441.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s2 = s.append(s1)

# %%
s2
# Out:
# a                               Heikkinen, Miss. Laina
# b         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                             Allen, Mr. William Henry
# d                                     Moran, Mr. James
# e                              McCarthy, Mr. Timothy J
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
s2 * 2  # it will do nothing
# Out:
# a         Heikkinen, Miss. LainaHeikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)Fu...
# c     Allen, Mr. William HenryAllen, Mr. William Henry
# d                     Moran, Mr. JamesMoran, Mr. James
# e       McCarthy, Mr. Timothy JMcCarthy, Mr. Timothy J
# 5                     Moran, Mr. JamesMoran, Mr. James
# 6       McCarthy, Mr. Timothy JMcCarthy, Mr. Timothy J
# 7    Palsson, Master. Gosta LeonardPalsson, Master....
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Be...
# 9    Nasser, Mrs. Nicholas (Adele Achem)Nasser, Mrs...
# dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# drop column

df.drop("PassengerId")  # it will give error bcs in this axis = 0 which means x - axis and columns is in y - axis.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 3
#       1 # drop column
# ----> 3 df.drop("PassengerId")  # it will give error bcs in this axis = 0 which means x - axis and columns is in y - axis.
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.drop("PassengerId",axis = 1)

# %%
df.head()

# %%
#  PassengerId column is present in the dataframe. It is only temporarily deleted

# %%
# to permanent delete

df.drop("PassengerId" , axis = 1 , inplace=True)

# %%
df.head()

# %%
#  drop row
df.drop(3)

# %%
df.head()

# %%
#  but it is not permanently deleted

df.drop(3, inplace = True)

# %%
df.head()

# %%
#  now the indexes of entire data are in built. If we want to make name column as index

df.set_index("Name")

# %%
df.head()

# %%
#  but it is not permanently set

df.set_index("Name" , inplace = True)

# %%
df.head(10)

# %%
#  now if i want to access the row 3

df.loc["Heikkinen, Miss. Laina"]

# %%
# however if i want to use iloc[] i can use

df.iloc[2]

# %%
# if i would like to get back to my original indexes
df.reset_index()  # it also fills the index diff that i have created by dropping the row 3

# %%
df.head()

# %%
#  to permanently reset

df.reset_index(inplace=True)

# %%
df

# %%
# CREATING DATAFRAME
d1 = {
    "Name" : ["Shashank" , "Mohan" , "Sohan" , "Rakesh"],  # value can be a list
    "Age" : [ 20 , 30 , 40 , 50],
    "City" : ["Safidon" , "Panipat" , "Hisar" , "Faridabad"]
}

df1 = pd.DataFrame(d1)  # all list must have same length
df1

# %%
df = pd.read_csv("titanic_dataset.csv")

# %%
df

# %%
#  to delete NaN values we use dropna()

df.dropna()   # by default it will remove all the rows which contains NaN value

# because axis = 0

# %%
df

# %%
#  but the rows are not permanently deleted.
#  to permanent delete the rows with NaN values we can use either reassignment or inplace = True

#df = df.dropna()   # df.dropna(inplace = True)

# %%
#  to  delet the column with NaN value

df.dropna(axis = 1)

# %%
#  but it is also not permanently deleted 

# df = df.dropna(axis = 1)  or  df.dropna(axis = 1 , inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# If we want to fill the NaN values 

df.fillna("sudh")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#  also it is permanently filled

#  to do it permanently

# df.fillna("kaku" , inplace = True) or df = df.fillna("kaku")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_fare
# 0      0         A/5 21171   7.2500   NaN        S   580.000
# 1      0          PC 17599  71.2833   C85        C  5702.664
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000
# 3      0            113803  53.1000  C123        S  4248.000
# ...

# %%
#  Now if we want to group similar data of survived column together 

df.groupby("Survived")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# NOw we want to know the average fair paid by survived and died person

df.groupby("Survived").mean()
# Out:
# /tmp/ipykernel_433/2338409843.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Survived").mean()
#           PassengerId    Pclass        Age     SibSp     Parch       Fare  \
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408
#
#              new_fare
# Survived
# 0         1769.430951
# 1         3871.632608

# %%
#  if we have to find the total sum of fare paid by survived and non - survived

df.groupby("Survived").sum()

# %%
#  same we have to find for male and female

df.groupby("Sex")

# %%
df.groupby("Sex").mean()

# %%
df.groupby("Sex").sum()

# %%
#  if we just looking for fare columm

df.groupby("Sex").sum()["Fare"]

# %%
#  for passenger class

df.groupby("Pclass")

# %%
df.groupby("Pclass").mean()
# Out:
# /tmp/ipykernel_433/3573772437.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Pclass").mean()
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
df.groupby("Pclass").sum()
# Out:
# /tmp/ipykernel_433/6622528.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Pclass").sum()
#         PassengerId  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1             99705       136  7111.42     90     77  18177.4125
# 2             82056        87  5168.83     74     70   3801.8417
# 3            215625       119  8924.92    302    193   6714.6951

# %%
df3 = df.groupby("Pclass").sum()
# Out:
# /tmp/ipykernel_433/4158957327.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3 = df.groupby("Pclass").sum()

# %%
#  if i want to rotate the dataframe

df3.T # or  df3.transpose
# Out:
# Pclass                1           2            3
# PassengerId  99705.0000  82056.0000  215625.0000
# Survived       136.0000     87.0000     119.0000
# Age           7111.4200   5168.8300    8924.9200
# SibSp           90.0000     74.0000     302.0000
# Parch           77.0000     70.0000     193.0000
# Fare         18177.4125   3801.8417    6714.6951

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Now we will do dataframe concatenation

# %%
#  data frame concatenation are of two types -  vertical , horizontal

# %%
df4 = df[["PassengerId"	 , "Survived" ,	"Pclass"]][0:5]

# %%
df4
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3

# %%
df5 = df[["Sex" , "Age" , "Fare"]][5:10]

# %%
df5
# Out:
#       Sex   Age     Fare
# 5    male   NaN   8.4583
# 6    male  54.0  51.8625
# 7    male   2.0  21.0750
# 8  female  27.0  11.1333
# 9  female  14.0  30.0708

# %%
#  horizontal concatenation

pd.concat([df4 , df5])  

# first five rows of df5 will be Nan and last five rows of df4 will be NaN bcs of diff index.
# Out:
#    PassengerId  Survived  Pclass     Sex   Age     Fare
# 0          1.0       0.0     3.0     NaN   NaN      NaN
# 1          2.0       1.0     1.0     NaN   NaN      NaN
# 2          3.0       1.0     3.0     NaN   NaN      NaN
# 3          4.0       1.0     1.0     NaN   NaN      NaN
# 4          5.0       0.0     3.0     NaN   NaN      NaN
# 5          NaN       NaN     NaN    male   NaN   8.4583
# 6          NaN       NaN     NaN    male  54.0  51.8625
# 7          NaN       NaN     NaN    male   2.0  21.0750
# 8          NaN       NaN     NaN  female  27.0  11.1333
# 9          NaN       NaN     NaN  female  14.0  30.0708

# %%
#  Vertical concatenation

pd.concat([df4 , df5] , axis = 1)  # output will remain same as in above
# Out:
#    PassengerId  Survived  Pclass     Sex   Age     Fare
# 0          1.0       0.0     3.0     NaN   NaN      NaN
# 1          2.0       1.0     1.0     NaN   NaN      NaN
# 2          3.0       1.0     3.0     NaN   NaN      NaN
# 3          4.0       1.0     1.0     NaN   NaN      NaN
# 4          5.0       0.0     3.0     NaN   NaN      NaN
# 5          NaN       NaN     NaN    male   NaN   8.4583
# 6          NaN       NaN     NaN    male  54.0  51.8625
# 7          NaN       NaN     NaN    male   2.0  21.0750
# 8          NaN       NaN     NaN  female  27.0  11.1333
# 9          NaN       NaN     NaN  female  14.0  30.0708

# %%
#  if indexes were same 

df6 = df[["PassengerId"	 , "Survived" ,	"Pclass"]][0:5]

# %%
df6
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3

# %%
df7 = df[["Sex" , "Age" , "Fare"]][0:5]

# %%
df7
# Out:
#       Sex   Age     Fare
# 0    male  22.0   7.2500
# 1  female  38.0  71.2833
# 2  female  26.0   7.9250
# 3  female  35.0  53.1000
# 4    male  35.0   8.0500

# %%
df8 = pd.concat([df6,df7])  # horizontal

# %%
pd.concat([df6,df7] , axis = 1)   # vertically
# Out:
#    PassengerId  Survived  Pclass     Sex   Age     Fare
# 0            1         0       3    male  22.0   7.2500
# 1            2         1       1  female  38.0  71.2833
# 2            3         1       3  female  26.0   7.9250
# 3            4         1       1  female  35.0  53.1000
# 4            5         0       3    male  35.0   8.0500

# %%
df8
# Out:
#    PassengerId  Survived  Pclass     Sex   Age     Fare
# 0          1.0       0.0     3.0     NaN   NaN      NaN
# 1          2.0       1.0     1.0     NaN   NaN      NaN
# 2          3.0       1.0     3.0     NaN   NaN      NaN
# 3          4.0       1.0     1.0     NaN   NaN      NaN
# 4          5.0       0.0     3.0     NaN   NaN      NaN
# 0          NaN       NaN     NaN    male  22.0   7.2500
# 1          NaN       NaN     NaN  female  38.0  71.2833
# 2          NaN       NaN     NaN  female  26.0   7.9250
# 3          NaN       NaN     NaN  female  35.0  53.1000
# 4          NaN       NaN     NaN    male  35.0   8.0500

# %%
df8.fillna("sudh")
# Out:
#   PassengerId Survived Pclass     Sex   Age     Fare
# 0         1.0      0.0    3.0    sudh  sudh     sudh
# 1         2.0      1.0    1.0    sudh  sudh     sudh
# 2         3.0      1.0    3.0    sudh  sudh     sudh
# 3         4.0      1.0    1.0    sudh  sudh     sudh
# 4         5.0      0.0    3.0    sudh  sudh     sudh
# 0        sudh     sudh   sudh    male  22.0     7.25
# 1        sudh     sudh   sudh  female  38.0  71.2833
# 2        sudh     sudh   sudh  female  26.0    7.925
# 3        sudh     sudh   sudh  female  35.0     53.1
# 4        sudh     sudh   sudh    male  35.0     8.05

# %%
df8 = df8.fillna("sudh")

# %%
df8
# Out:
#   PassengerId Survived Pclass     Sex   Age     Fare
# 0         1.0      0.0    3.0    sudh  sudh     sudh
# 1         2.0      1.0    1.0    sudh  sudh     sudh
# 2         3.0      1.0    3.0    sudh  sudh     sudh
# 3         4.0      1.0    1.0    sudh  sudh     sudh
# 4         5.0      0.0    3.0    sudh  sudh     sudh
# 0        sudh     sudh   sudh    male  22.0     7.25
# 1        sudh     sudh   sudh  female  38.0  71.2833
# 2        sudh     sudh   sudh  female  26.0    7.925
# 3        sudh     sudh   sudh  female  35.0     53.1
# 4        sudh     sudh   sudh    male  35.0     8.05

# %%
#  merge operations[this operations check columns]

# %%
d1 = {"key1" : [1,2,4,5,6] , "key2" : [4,5,6,7,8] , "key3" : [3,4,5,6,6]}

data1 = pd.DataFrame(d1)

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
d2 = {"key1" : [1,2,45,6,67] , "key4" : [56,5,6,7,8] , "key5" : [3,56,5,6,6]}

# %%
data2 = pd.DataFrame(d2)

# %%
data2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
pd.merge(data1 , data2)  # by default how = "inner"
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3    56     3
# 1     2     5     4     5    56
# 2     6     8     6     7     6

# %%
pd.merge(data1 , data2 ,how = "left")
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3  56.0   3.0
# 1     2     5     4   5.0  56.0
# 2     4     6     5   NaN   NaN
# 3     5     7     6   NaN   NaN
# 4     6     8     6   7.0   6.0

# %%
pd.merge(data1 , data2 , how = "right")
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0    56     3
# 1     2   5.0   4.0     5    56
# 2    45   NaN   NaN     6     5
# 3     6   8.0   6.0     7     6
# 4    67   NaN   NaN     8     6

# %%
pd.merge(data1 , data2 , how = "outer")
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0  56.0   3.0
# 1     2   5.0   4.0   5.0  56.0
# 2     4   6.0   5.0   NaN   NaN
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   7.0   6.0
# 5    45   NaN   NaN   6.0   5.0
# 6    67   NaN   NaN   8.0   6.0

# %%
pd.merge(data1 , data2 , how = "inner")
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3    56     3
# 1     2     5     4     5    56
# 2     6     8     6     7     6

# %%
pd.merge(data1 , data2 , how = "cross")
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1    56     3
# 1        1     4     3       2     5    56
# 2        1     4     3      45     6     5
# 3        1     4     3       6     7     6
# 4        1     4     3      67     8     6
# 5        2     5     4       1    56     3
# 6        2     5     4       2     5    56
# 7        2     5     4      45     6     5
# 8        2     5     4       6     7     6
# 9        2     5     4      67     8     6
# 10       4     6     5       1    56     3
# 11       4     6     5       2     5    56
# 12       4     6     5      45     6     5
# 13       4     6     5       6     7     6
# 14       4     6     5      67     8     6
# 15       5     7     6       1    56     3
# 16       5     7     6       2     5    56
# 17       5     7     6      45     6     5
# 18       5     7     6       6     7     6
# 19       5     7     6      67     8     6
# 20       6     8     6       1    56     3
# ...

# %%
pd.merge(data1 , data2 ,how = "left" , on = "key1")  # if i purposly specifies column on which merge is to be done
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3  56.0   3.0
# 1     2     5     4   5.0  56.0
# 2     4     6     5   NaN   NaN
# 3     5     7     6   NaN   NaN
# 4     6     8     6   7.0   6.0

# %%
pd.merge(data1 , data2 ,how = "left" , left_on = "key2" , right_on = "key4")
# Out:
#    key1_x  key2  key3  key1_y  key4  key5
# 0       1     4     3     NaN   NaN   NaN
# 1       2     5     4     2.0   5.0  56.0
# 2       4     6     5    45.0   6.0   5.0
# 3       5     7     6     6.0   7.0   6.0
# 4       6     8     6    67.0   8.0   6.0

# %%
# join operations [ checks the index ]

# %%
d1 = {"key1" : [1,2,4,5,6] , "key2" : [4,5,6,7,8] , "key3" : [3,4,5,6,6] }

data1 = pd.DataFrame(d1 , index = ["a" , "b" , "c" ,"d" ,"e"])

# %%
data1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %%
d2 = {"key4" : [1,3,7,5,6] , "key5" : [2,6,5,7,8] , "key6" : [3,2,5,6,1] }

data2 = pd.DataFrame(d2 , index = ["a" , "b" , "h" ,"i" ,"j"])

# %%
data2
# Out:
#    key4  key5  key6
# a     1     2     3
# b     3     6     2
# h     7     5     5
# i     5     7     6
# j     6     8     1

# %%
data1.join(data2)   # By default it considers left
# Out:
#    key1  key2  key3  key4  key5  key6
# a     1     4     3   1.0   2.0   3.0
# b     2     5     4   3.0   6.0   2.0
# c     4     6     5   NaN   NaN   NaN
# d     5     7     6   NaN   NaN   NaN
# e     6     8     6   NaN   NaN   NaN

# %%
data1.join(data2 , how = "right")
# Out:
#    key1  key2  key3  key4  key5  key6
# a   1.0   4.0   3.0     1     2     3
# b   2.0   5.0   4.0     3     6     2
# h   NaN   NaN   NaN     7     5     5
# i   NaN   NaN   NaN     5     7     6
# j   NaN   NaN   NaN     6     8     1

# %%
data1.join(data2 , how = "inner")
# Out:
#    key1  key2  key3  key4  key5  key6
# a     1     4     3     1     2     3
# b     2     5     4     3     6     2

# %%
data1.join(data2 , how = "outer")
# Out:
#    key1  key2  key3  key4  key5  key6
# a   1.0   4.0   3.0   1.0   2.0   3.0
# b   2.0   5.0   4.0   3.0   6.0   2.0
# c   4.0   6.0   5.0   NaN   NaN   NaN
# d   5.0   7.0   6.0   NaN   NaN   NaN
# e   6.0   8.0   6.0   NaN   NaN   NaN
# h   NaN   NaN   NaN   7.0   5.0   5.0
# i   NaN   NaN   NaN   5.0   7.0   6.0
# j   NaN   NaN   NaN   6.0   8.0   1.0

# %%
data1.join(data2 , how = "cross")
# Out:
#     key1  key2  key3  key4  key5  key6
# 0      1     4     3     1     2     3
# 1      1     4     3     3     6     2
# 2      1     4     3     7     5     5
# 3      1     4     3     5     7     6
# 4      1     4     3     6     8     1
# 5      2     5     4     1     2     3
# 6      2     5     4     3     6     2
# 7      2     5     4     7     5     5
# 8      2     5     4     5     7     6
# 9      2     5     4     6     8     1
# 10     4     6     5     1     2     3
# 11     4     6     5     3     6     2
# 12     4     6     5     7     5     5
# 13     4     6     5     5     7     6
# 14     4     6     5     6     8     1
# 15     5     7     6     1     2     3
# 16     5     7     6     3     6     2
# 17     5     7     6     7     5     5
# 18     5     7     6     5     7     6
# 19     5     7     6     6     8     1
# 20     6     8     6     1     2     3
# 21     6     8     6     3     6     2
# 22     6     8     6     7     5     5
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# if we are asked to create a new column in which fare value is converted into INR.

#  apply()

df["new_fare"] = df["Fare"].apply(lambda x: x*80)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_fare
# 0      0         A/5 21171   7.2500   NaN        S   580.000
# 1      0          PC 17599  71.2833   C85        C  5702.664
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000
# 3      0            113803  53.1000  C123        S  4248.000
# ...

# %%
#  if we are asked to create a column which contains lenth of name 

df["name_length"] = df["Name"].apply(len)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_fare  name_length
# 0      0         A/5 21171   7.2500   NaN        S   580.000           23
# 1      0          PC 17599  71.2833   C85        C  5702.664           51
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000           22
# ...

# %%
# if we are asked to create a column which has 

def create_flag(x):
    if x < 10:
        return "cheap"
    
    elif x >=10 and x < 20:
        return "mid"
    else:
        return "high"

# %%
df["Flag_fare"] = df["Fare"].apply(create_flag)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_fare  name_length  \
# 0      0         A/5 21171   7.2500   NaN        S   580.000           23
# 1      0          PC 17599  71.2833   C85        C  5702.664           51
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000           22
# ...
