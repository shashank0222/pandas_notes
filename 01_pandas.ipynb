# %%
import pandas as pd

# %%
pd.read_csv("services.csv")
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
#  by default the first row will be considered as the header
# to remove this setting we have to add header = None
df = pd.read_csv("services.csv" , header = None)

# %%
df = pd.read_csv("services.csv")
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
#  we can add these columns in a list

list(df.columns)
# Out:
# ['id',
#  'location_id',
#  'program_id',
#  'accepted_payments',
#  'alternate_name',
#  'application_process',
#  'audience',
#  'description',
#  'eligibility',
#  'email',
#  'fees',
#  'funding_sources',
#  'interpretation_services',
#  'keywords',
#  'languages',
#  'name',
#  'required_documents',
#  'service_areas',
#  'status',
#  'wait_time',
#  'website',
#  'taxonomy_ids']

# %%
#  If we want to get only limited records, then we use head() method
# by default this method gives first five rows .

df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
#  if add some number in the head() method , it will give those first number of records

df.head(10)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
# 5   6            6         NaN               NaN            NaN
# 6   7            7         NaN               NaN            NaN
# 7   8            8         NaN               NaN            NaN
# 8   9            9         NaN               NaN            NaN
# 9  10           10         NaN               NaN            NaN
#
#                                  application_process  \
# 0                         Walk in or apply by phone.
# 1                 Apply by phone for an appointment.
# 2        Phone for information (403-4300 Ext. 4322).
# ...

# %%
#  if we want to get records from last ,then we'll use tail() method
# By default , it will give last five records.
#  but we can set this number.

df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
df.tail(10)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# 15  16           16         NaN                       NaN
# 16  17           17         NaN                       NaN
# 17  18           18         NaN                       NaN
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                                application_process  \
# 13                    NaN  Call for appointment. Referral from human serv...
# 14                    NaN          Walk in or through other agency referral.
# 15                    NaN  Walk in. Written application, identification r...
# ...

# %%
#  we can see that each column has data of different data types
#  we can find the data type of each column by using dtypes
#  IN pandas , object is eqiv to string.
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df['email']
# Out:
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21    passports@example.org
# 22                      NaN
# Name: email, dtype: object

# %%
#  If we find the type of it , it is a series
#  Series is equiv to list but the main diff is that it gives idexes also.

type(df['email'])
# Out:
# pandas.core.series.Series

# %%
#  if we convert it into a list , the properties will almost same  but not exactly same.


list(df["email"])
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'passports@example.org',
#  nan]

# %%
#  IF we pass the column as a list, it becomes a dataframe.

df[['email']]
# Out:
#                     email
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12                    NaN
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16                    NaN
# 17                    NaN
# 18                    NaN
# 19                    NaN
# 20                    NaN
# 21  passports@example.org
# 22                    NaN

# %%
type(df[["email"]])
# Out:
# pandas.core.frame.DataFrame

# %%
#  now , can we get the data of two columns ?

# df["email" , "status"]   --> no it will give an error
#  we can add only one one column as a string.

# %%
#  if i want to pass multiple columns , then i will have to pass it in a list

# %%
df[["email" , "status"]]  # we can add columns in any order.
# Out:
#                     email    status
# 0                     NaN    active
# 1                     NaN    active
# 2                     NaN    active
# 3                     NaN    active
# 4                     NaN    active
# 5                     NaN    active
# 6                     NaN    active
# 7                     NaN    active
# 8                     NaN    active
# 9                     NaN    active
# 10                    NaN    active
# 11                    NaN    active
# 12                    NaN    active
# 13                    NaN    active
# 14                    NaN    active
# 15                    NaN    active
# 16                    NaN    active
# 17                    NaN    active
# 18                    NaN    active
# 19                    NaN   defunct
# 20                    NaN  inactive
# 21  passports@example.org    active
# 22                    NaN    active

# %%
#  similary  we can read an excel file and do all the above operations.

df1 = pd.read_excel("LUSID Excel - Setting up your market data.xlsx")

# %%
df1.head(3)
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0         NaN         NaN         NaN                 NaN        NaN
# 1         NaN         NaN         NaN  Datetimes in LUSID        NaN
# 2         NaN         NaN         NaN                 NaN        NaN
#
#   Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN         NaN        NaN        NaN        NaN
# 1        NaN         NaN        NaN        NaN        NaN
# 2        NaN         NaN        NaN        NaN        NaN

# %%
df1.tail(3)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 25         NaN         NaN         NaN        NaN
# 26         NaN         NaN         NaN        NaN
# 27         NaN         NaN         NaN        NaN
#
#                               Unnamed: 4                  Unnamed: 5  \
# 25          Add an hour to your datetime  2019-04-10 14:30:45.550000
# 26                                   NaN                         NaN
# 27  Subtract a minute from your datetime  2019-04-10 14:29:45.550000
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 25         NaN        NaN        NaN        NaN
# 26         NaN        NaN        NaN        NaN
# 27         NaN        NaN        NaN        NaN

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
df1['Unnamed: 2']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# Name: Unnamed: 2, dtype: float64

# %%
type(df1['Unnamed: 2'])
# Out:
# pandas.core.series.Series

# %%
df1[['Unnamed: 0', 'Unnamed: 1']]
# Out:
#     Unnamed: 0  Unnamed: 1
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11         NaN         NaN
# 12         NaN         NaN
# 13         NaN         NaN
# 14         NaN         NaN
# 15         NaN         NaN
# 16         NaN         NaN
# 17         NaN         NaN
# 18         NaN         NaN
# 19         NaN         NaN
# 20         NaN         NaN
# 21         NaN         NaN
# 22         NaN         NaN
# 23         NaN         NaN
# 24         NaN         NaN
# 25         NaN         NaN
# 26         NaN         NaN
# 27         NaN         NaN

# %%
df1.dtypes
# Out:
# Unnamed: 0    float64
# Unnamed: 1    float64
# Unnamed: 2    float64
# Unnamed: 3     object
# Unnamed: 4     object
# Unnamed: 5     object
# Unnamed: 6    float64
# Unnamed: 7     object
# Unnamed: 8     object
# Unnamed: 9     object
# dtype: object

# %%
df2 = pd.read_csv("https://media.githubusercontent.com/media/datablist/sample-csv-files/main/files/people/people-1000.csv")

# %%
df2
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# ...

# %%
df2.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
#
#                            Email            Phone Date of birth  \
# 0            pwarner@example.org     857.139.8239    2014-01-27
# 1  fergusonkatherine@example.net  +1-950-759-8687    1931-07-26
# 2            fhoward@example.org    (599)782-0605    2013-11-25
#
#            Job Title
# 0  Probation officer
# 1             Dancer
# 2               Copy

# %%
df2.tail(6)
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 994    995  E54d5DDEeE6569E    Beverly      Ball    Male
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                           Email                  Phone Date of birth  \
# 994  charlenehuerta@example.com       573-943-0389x380    1995-07-01
# 995      lyonsdaisy@example.net           021.775.2933    1959-01-05
# 996     dariusbryan@example.com   001-149-710-7799x721    2001-10-06
# 997      georgechan@example.org  +1-750-774-4128x33265    1918-05-13
# 998         wanda04@example.net          (915)292-2254    1971-08-31
# 999     deannablack@example.org     079.752.5424x67259    1947-01-24
#
#                            Job Title
# 994        Publishing rights manager
# ...

# %%
df2.columns
# Out:
# Index(['Index', 'User Id', 'First Name', 'Last Name', 'Sex', 'Email', 'Phone',
#        'Date of birth', 'Job Title'],
#       dtype='object')

# %%
df2['First Name']
# Out:
# 0        Shelia
# 1            Jo
# 2        Sheryl
# 3       Whitney
# 4       Lindsey
#          ...
# 995        Kurt
# 996       Donna
# 997       Cathy
# 998    Jermaine
# 999         Lee
# Name: First Name, Length: 1000, dtype: object

# %%
df2[[ 'Email', 'Phone']]
# Out:
#                              Email                  Phone
# 0              pwarner@example.org           857.139.8239
# 1    fergusonkatherine@example.net        +1-950-759-8687
# 2              fhoward@example.org          (599)782-0605
# 3            zjohnston@example.com        +1-939-130-6258
# 4                 elin@example.net     (390)417-1635x3010
# ..                             ...                    ...
# 995         lyonsdaisy@example.net           021.775.2933
# 996        dariusbryan@example.com   001-149-710-7799x721
# 997         georgechan@example.org  +1-750-774-4128x33265
# 998            wanda04@example.net          (915)292-2254
# 999        deannablack@example.org     079.752.5424x67259
#
# [1000 rows x 2 columns]

# %%
# Now if we want to store this csv file in our local system

df2.to_csv("people_data.csv")

# %%
#  You can see in the file that it is even try to store indexes , which we does not want those indexes

df2.to_csv("people_modified_data.csv" , index = False)

# %%
#  Now, sometimes we have to read the tabular data and there can be any number of tables in a page
# lets see how we deals with them
import lxml , pandas as pd
df3 = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2020_per_game.html")

# %%
 type(df3)
# Out:
# list

# %%
len(df3)
# Out:
# 1

# %%
df3[0]
# Out:
#       Rk                    Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1              Steven Adams   C  26  OKC  63  63  26.7  4.5   7.6  ...
# 1      2               Bam Adebayo  PF  22  MIA  72  72  33.6  6.1  11.0  ...
# 2      3         LaMarcus Aldridge   C  34  SAS  53  53  33.1  7.4  15.0  ...
# 3      4            Kyle Alexander   C  23  MIA   2   0   6.5  0.5   1.0  ...
# 4      5  Nickeil Alexander-Walker  SG  21  NOP  47   1  12.6  2.1   5.7  ...
# ..   ...                       ...  ..  ..  ...  ..  ..   ...  ...   ...  ...
# 672  525                Trae Young  PG  21  ATL  60  60  35.3  9.1  20.8  ...
# 673  526               Cody Zeller   C  27  CHO  58  39  23.1  4.3   8.3  ...
# 674  527              Tyler Zeller   C  30  SAS   2   0   2.0  0.5   2.0  ...
# 675  528                Ante Žižić   C  23  CLE  22   0  10.0  1.9   3.3  ...
# 676  529               Ivica Zubac   C  22  LAC  72  70  18.4  3.3   5.3  ...
#
# ...

# %%
type(df3[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df3[0].columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df3[0]["Player"]
# Out:
# 0                  Steven Adams
# 1                   Bam Adebayo
# 2             LaMarcus Aldridge
# 3                Kyle Alexander
# 4      Nickeil Alexander-Walker
#                  ...
# 672                  Trae Young
# 673                 Cody Zeller
# 674                Tyler Zeller
# 675                  Ante Žižić
# 676                 Ivica Zubac
# Name: Player, Length: 677, dtype: object

# %%
df3[0][['Tm', 'G', 'GS']]
# Out:
#       Tm   G  GS
# 0    OKC  63  63
# 1    MIA  72  72
# 2    SAS  53  53
# 3    MIA   2   0
# 4    NOP  47   1
# ..   ...  ..  ..
# 672  ATL  60  60
# 673  CHO  58  39
# 674  SAS   2   0
# 675  CLE  22   0
# 676  LAC  72  70
#
# [677 rows x 3 columns]

# %%
df4 = df3[0]

# %%
df4.to_csv("players.csv" , index = False)
